# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#read data into a dataframe

# %%
data = pd.read_csv("https://raw.githubusercontent.com/huanfachen/QM_2024/refs/heads/main/data/daily_count_rent_bike.csv" , index_col=0)

# %%
data.head(n=10)
# Out:
#       season    yr mnth     holiday weekday      workingday weathersit  \
# cnt
# 985   SPRING  2011  JAN  NO HOLIDAY     SAT  NO WORKING DAY      MISTY
# 801   SPRING  2011  JAN  NO HOLIDAY     SUN  NO WORKING DAY      MISTY
# 1349  SPRING  2011  JAN  NO HOLIDAY     MON     WORKING DAY       GOOD
# 1562  SPRING  2011  JAN  NO HOLIDAY     TUE     WORKING DAY       GOOD
# 1600  SPRING  2011  JAN  NO HOLIDAY     WED     WORKING DAY       GOOD
# 1606  SPRING  2011  JAN  NO HOLIDAY     THU     WORKING DAY       GOOD
# 1510  SPRING  2011  JAN  NO HOLIDAY     FRI     WORKING DAY      MISTY
# 959   SPRING  2011  JAN  NO HOLIDAY     SAT  NO WORKING DAY      MISTY
# 822   SPRING  2011  JAN  NO HOLIDAY     SUN  NO WORKING DAY       GOOD
# 1321  SPRING  2011  JAN  NO HOLIDAY     MON     WORKING DAY       GOOD
#
#           temp      hum  windspeed  days_since_2011
# cnt
# 985   8.175849  80.5833  10.749882                0
# 801   9.083466  69.6087  16.652113                1
# ...

# %%
data.shape
# Out:
# (731, 11)

# %%
data = data.drop(columns=['season', 'days_since_2011'])

# %%
data.head(n=20)
# Out:
#         yr mnth     holiday weekday      workingday weathersit      temp  \
# cnt
# 985   2011  JAN  NO HOLIDAY     SAT  NO WORKING DAY      MISTY  8.175849
# 801   2011  JAN  NO HOLIDAY     SUN  NO WORKING DAY      MISTY  9.083466
# 1349  2011  JAN  NO HOLIDAY     MON     WORKING DAY       GOOD  1.229108
# 1562  2011  JAN  NO HOLIDAY     TUE     WORKING DAY       GOOD  1.400000
# 1600  2011  JAN  NO HOLIDAY     WED     WORKING DAY       GOOD  2.666979
# 1606  2011  JAN  NO HOLIDAY     THU     WORKING DAY       GOOD  1.604356
# 1510  2011  JAN  NO HOLIDAY     FRI     WORKING DAY      MISTY  1.236534
# 959   2011  JAN  NO HOLIDAY     SAT  NO WORKING DAY      MISTY -0.245000
# 822   2011  JAN  NO HOLIDAY     SUN  NO WORKING DAY       GOOD -1.498349
# 1321  2011  JAN  NO HOLIDAY     MON     WORKING DAY       GOOD -0.910849
# 1263  2011  JAN  NO HOLIDAY     TUE     WORKING DAY      MISTY -0.052723
# 1162  2011  JAN  NO HOLIDAY     WED     WORKING DAY       GOOD  0.118169
# ...
